# %%
# %pip install -e /Workspace/Users/bjturner@outlook.com/ocel-2.0-event-log-analysis

# %%
from utils import ocel2_uc_importer

# %%
list_all = ['a', 'b', 'c', 'd']
list_some = ['a', None, 'c', None]

boolean_all = all([x is not None for x in list_all])
boolean_some = all([x is not None for x in list_some])
print(boolean_all)
print(boolean_some)

# %%
ocel2_json = ocel2_uc_importer.OCEL2UCImporter(
    url = "https://zenodo.org/records/18373888/files/container_logistics.json?download=1",
    catalog = "ocel",
    schema = "logistics",
    volume = "volume",
)
ocel2_json.

# %%
ocel2_json.download_file(file_name="container_logistics.json")

# %%
ocel2_json.write_ocel2_json_to_schema()

# %%
# Add the parent directory to Python's path

print(parent_dir)
# sys.path.insert(0, str(parent_dir))

# # Now you can import from the ingest folder
# from ingest import your_script_name

# # Or run specific functions
# your_script_name.some_function()

# %%
# Downloads ocel file from public repository
file_url = "https://zenodo.org/records/8428084/files/ContainerLogistics.json?download=1"
catalog, schema, volume = 'ocel', 'logistics', 'volume'
volume_path = f"/Volumes/{catalog}/{schema}/{volume}"
file_name = "container_logistics.json"
download.download_file(file_url, volume_path, file_name)

# %%
# Unnests ocel file into Unity Catalog-managed tables
file_path = os.path.join(volume_path, file_name)
converter = write.OCELToUCSChema(spark, catalog, schema)
converter.convert_json(file_path)

# %%
ocel.get_summary()

# %%
ocel.is_ocel20()

# %%
type(ocel.event_activity)

# %%
ocel.relations

# %%
ocel.objects[ocel.objects["ocel:oid"]=="td1"]

# %%
ocel.objects[ocel.objects["ocel:type"]=="Transport Document"]

# %%
help(pm4py.read_ocel2_sqlite)
